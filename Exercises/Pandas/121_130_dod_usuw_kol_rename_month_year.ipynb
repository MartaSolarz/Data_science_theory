# %% [markdown]
# <a href="https://colab.research.google.com/github/MartaSolarz/Data_science_theory/blob/main/Exercises/Pandas/121_130_dod_usuw_kol_rename_month_year.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Pandas
#
# ### Spis treści:
# * [Import biblioteki](#0)
# * [Ćwiczenie 121](#1)
# * [Ćwiczenie 122](#2)
# * [Ćwiczenie 123](#3)
# * [Ćwiczenie 124](#4)
# * [Ćwiczenie 125](#5)
# * [Ćwiczenie 126](#6)
# * [Ćwiczenie 127](#7)
# * [Ćwiczenie 128](#8)
# * [Ćwiczenie 129](#9)
# * [Ćwiczenie 130](#10)

# %% [markdown]
# ### <a name='0'></a>Import biblioteki

# %%
import numpy as np
import pandas as pd
import seaborn as sns

sns.set()
np.__version__
# Out:
# '1.21.6'

# %% [markdown]
# Funkcja _fetch_financial_data()_ pobiera dane dotyczące notowań spółek giełdowych. Będzie wykorzystywana w poniższych ćwiczeniach. Aby pobrać dane konkretnej spółki należy przekazać odpowiedni ticker (symbol) spółki.
#
# Kilka przykładowych tickerów spółek:
# * AMZN - Amazon
# * GOOGL - Google
# * MSFT - Microsoft
# * AAPL - Apple
# * NKE - Nike
# * WMT - Walmart

# %%
def fetch_financial_data(company='AMZN'):
    """
    This function fetches stock market quotations.
    """
    import pandas_datareader.data as web
    return web.DataReader(name=company, data_source='stooq')

# %% [markdown]
# ### <a name='1'></a> Ćwiczenie 121
# Wykorzystując funkcję _fetch_financial_data()_ pobierz notowania dla spółki Google (Alphabet) i przypisz do zmiennej _google_. Wyświetl obiekt _google_.

# %%
# tutaj wpisz rozwiązanie

google = fetch_financial_data(company='GOOGL')

google
# Out:
#              Open   High    Low  Close    Volume
# Date
# 2022-08-30 110.17 110.50 107.80 108.94  27513255
# 2022-08-29 109.99 110.95 108.80 109.42  21191157
# 2022-08-26 114.72 115.12 110.19 110.34  37245697
# 2022-08-25 114.23 116.72 114.11 116.65  16956794
# 2022-08-24 113.50 114.78 112.87 113.69  17734624
# ...           ...    ...    ...    ...       ...
# 2017-09-08  47.48  47.53  47.00  47.05  19995660
# 2017-09-07  47.21  47.52  46.88  47.49  22325520
# 2017-09-06  47.19  47.23  46.63  47.10  27824300
# 2017-09-05  47.34  47.57  46.78  47.07  29173820
# 2017-09-01  47.87  47.92  47.51  47.60  20853720
#
# [1257 rows x 5 columns]

# %% [markdown]
# ### <a name='2'></a> Ćwiczenie 122
# Wyświetl podstawowe informacje na temat obiektu _google_.

# %%
# tutaj wpisz rozwiązanie

google.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1257 entries, 2022-08-30 to 2017-09-01
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Open    1257 non-null   float64
#  1   High    1257 non-null   float64
#  2   Low     1257 non-null   float64
#  3   Close   1257 non-null   float64
#  4   Volume  1257 non-null   int64
# dtypes: float64(4), int64(1)
# memory usage: 58.9 KB

# %% [markdown]
# Wyświetl podstawowe statystyki o obiekcie _google_.

# %%
# tutaj wpisz rozwiązanie

google.describe()
# Out:
#          Open    High     Low   Close       Volume
# count 1257.00 1257.00 1257.00 1257.00      1257.00
# mean    82.59   83.48   81.70   82.61  35238255.83
# std     31.77   32.08   31.39   31.73  16066618.88
# min     46.67   46.84   46.23   46.49   9312760.00
# 25%     56.65   57.31   56.16   56.75  25110140.00
# 50%     67.60   68.22   67.21   67.60  31343220.00
# 75%    112.64  114.01  111.46  112.72  40143880.00
# max    151.25  151.55  148.90  149.84 133177100.00

# %% [markdown]
# Zwróć uwagę na precyzję zapisu poszczególnych statystyk.
# Spróbuj ustawić odpowiednie opcje biblioteki _pandas_, tak aby wyświetlać dane z dokładnością do dwóch miejsc po przecinku.
#
# __Wskazówka:__
# https://pandas.pydata.org/pandas-docs/stable/user_guide/options.html

# %%
# tutaj wpisz rozwiązanie

pd.options.display.precision = 2

# %% [markdown]
# __Dodatkowo:__
# Poniższe ustawienie stłumi także notację wykładniczą (patrz kolumna _Volume_).

# %%
pd.options.display.float_format = '{:.2f}'.format
google.describe()
# Out:
#          Open    High     Low   Close       Volume
# count 1257.00 1257.00 1257.00 1257.00      1257.00
# mean    82.59   83.48   81.70   82.61  35238255.83
# std     31.77   32.08   31.39   31.73  16066618.88
# min     46.67   46.84   46.23   46.49   9312760.00
# 25%     56.65   57.31   56.16   56.75  25110140.00
# 50%     67.60   68.22   67.21   67.60  31343220.00
# 75%    112.64  114.01  111.46  112.72  40143880.00
# max    151.25  151.55  148.90  149.84 133177100.00

# %% [markdown]
# Zbuduj wykres ceny zamknięcia (_Close_) dla obiektu _google_.

# %%
# tutaj wpisz rozwiązanie

google['Close'].plot();

# %% [markdown]
# ### <a name='3'></a> Ćwiczenie 123
# Zamień indeks _Date_ na kolumnę. Przypisz trwale zmiany do zniennej _google_.

# %%
# tutaj wpisz rozwiązanie

google.reset_index(inplace=True)

google.head()
# Out:
#         Date   Open   High    Low  Close    Volume
# 0 2022-08-30 110.17 110.50 107.80 108.94  27513255
# 1 2022-08-29 109.99 110.95 108.80 109.42  21191157
# 2 2022-08-26 114.72 115.12 110.19 110.34  37245697
# 3 2022-08-25 114.23 116.72 114.11 116.65  16956794
# 4 2022-08-24 113.50 114.78 112.87 113.69  17734624

# %% [markdown]
# Przypisz dwie nowe kolumny do obiektu _google_ dodając kolumnę z aktualnym numerem miesiąca o nazwie _'Month'_ oraz z rokiem o nazwie _'Year'_.

# %%
# tutaj wpisz rozwiązanie

google['Month'] = google['Date'].apply(lambda x: x.month)
google['Year'] = google['Date'].apply(lambda x: x.year)
google.sample(3)
# Out:
#            Date   Open   High    Low  Close    Volume  Month  Year
# 887  2019-02-22  55.48  55.86  55.02  55.83  29435660      2  2019
# 1207 2017-11-10  52.19  52.33  52.06  52.21  19409960     11  2017
# 276  2021-07-27 134.25 134.40 130.10 131.90  54709480      7  2021

# %% [markdown]
# ### <a name='4'></a> Ćwiczenie 124
# Policz średnią cenę zamknięcia (_Close_) dla poszczególnego roku (pogrupuj dane po roku - kolumna _Year_ i następnie policz wartość średnią).

# %%
# tutaj wpisz rozwiązanie

year_group = google.groupby(by='Year')['Close'].mean()

year_group
# Out:
# Year
# 2017    50.58
# 2018    56.10
# 2019    59.56
# 2020    73.95
# 2021   124.22
# 2022   123.73
# Name: Close, dtype: float64

# %% [markdown]
# Otrzymane wartości przedstaw na wykresie wykorzystując metodę _plot()_.

# %%
# tutaj wpisz rozwiązanie

year_group.plot();

# %% [markdown]
# Policz średnią cenę zamknięcia (_Close_) dla miesiąca (pogrupuj dane po miesiącu - kolumna _Month_ i następnie policz wartość średnią).

# %%
# tutaj wpisz rozwiązanie

month_group = google.groupby(by='Month')

month_group['Close'].mean()
# Out:
# Month
# 1    81.07
# 2    84.69
# 3    83.23
# 4    82.93
# 5    81.15
# 6    83.85
# 7    86.31
# 8    90.54
# 9    77.67
# 10   76.07
# 11   81.04
# 12   82.65
# Name: Close, dtype: float64

# %% [markdown]
# Otrzymane wartości przedstaw na wykresie wykorzystując metodę _plot()_.
# Zauważ, które miesiące mogą wskazywać na słabsze okresy na giełdzie.

# %%
# tutaj wpisz rozwiązanie

month_group['Close'].mean().plot();

# %% [markdown]
# ### <a name='5'></a> Ćwiczenie 125
# Pogrupuj dane z obiektu _google_ na poziomie roku i miesiąca. Następnie policz wartość średnią.

# %%
# tutaj wpisz rozwiązanie

y_m_group = google.groupby(by=['Year', 'Month'])

y_m_group['Close'].mean()
# Out:
# Year  Month
# 2017  9        47.29
#       10       49.96
#       11       52.35
#       12       52.69
# 2018  1        56.97
#       2        54.60
#       3        54.69
#       4        52.00
#       5        53.74
#       6        57.47
#       7        60.06
#       8        62.03
#       9        59.25
#       10       56.06
#       11       53.31
#       12       52.40
# 2019  1        54.05
#       2        56.07
#       3        59.22
#       4        61.57
#       5        57.77
#       6        54.15
#       7        57.65
#       8        59.11
#       9        61.07
#       10       61.62
#       11       65.14
#       12       67.05
# 2020  1        71.81
#       2        73.14
#       3        59.26
#       4        61.51
#       5        69.07
#       6        71.58
#       7        75.77
#       8        77.25
#       9        75.58
#       10       77.10
#       11       87.17
#       12       88.39
# 2021  1        90.01
#       2       102.90
#       3       102.38
#       4       113.65
#       5       115.43
#       6       121.05
#       7       128.56
#       8       138.37
#       9       141.18
#       10      140.11
#       11      146.76
#       12      145.15
# 2022  1       135.96
#       2       136.71
#       3       134.98
#       4       128.07
#       5       113.19
#       6       112.43
#       7       112.65
#       8       116.62
# Name: Close, dtype: float64

# %% [markdown]
# ### <a name='6'></a> Ćwiczenie 126
# Znajdź indeks dla którego kolumna _Close_ przyjmuje wartość największą.

# %%
# tutaj wpisz rozwiązanie

google['Close'].argmax()
# Out:
# 195

# %% [markdown]
# Wytnij wiersz dla tego indeksu z obiektu _google_ jako obiekt DataFrame. Odczytaj datę.

# %%
# tutaj wpisz rozwiązanie

google.iloc[[google['Close'].argmax()]]
# Out:
#           Date   Open   High    Low  Close    Volume  Month  Year
# 195 2021-11-18 148.24 150.58 147.88 149.84  35628220     11  2021

# %% [markdown]
# ### <a name='7'></a> Ćwiczenie 127
# Z obiektu _google_ wytnij kolumny _Date_, _Open_, _Close_, _Volume_.
# Nie zmieniaj pierwotnego obiektu _google_!

# %%
# tutaj wpisz rozwiązanie

google[['Date', 'Open', 'Close', 'Volume']]
# Out:
#            Date   Open  Close    Volume
# 0    2022-08-30 110.17 108.94  27513255
# 1    2022-08-29 109.99 109.42  21191157
# 2    2022-08-26 114.72 110.34  37245697
# 3    2022-08-25 114.23 116.65  16956794
# 4    2022-08-24 113.50 113.69  17734624
# ...         ...    ...    ...       ...
# 1252 2017-09-08  47.48  47.05  19995660
# 1253 2017-09-07  47.21  47.49  22325520
# 1254 2017-09-06  47.19  47.10  27824300
# 1255 2017-09-05  47.34  47.07  29173820
# 1256 2017-09-01  47.87  47.60  20853720
#
# [1257 rows x 4 columns]

# %% [markdown]
# ### <a name='8'></a> Ćwiczenie 128
# Ustaw z powrotem indeks dla kolumny _Date_. Wyświetl obiekt _google_.

# %%
# tutaj wpisz rozwiązanie

google.set_index('Date', inplace=True)

# %%
google.head()
# Out:
#              Open   High    Low  Close    Volume  Month  Year
# Date
# 2022-08-30 110.17 110.50 107.80 108.94  27513255      8  2022
# 2022-08-29 109.99 110.95 108.80 109.42  21191157      8  2022
# 2022-08-26 114.72 115.12 110.19 110.34  37245697      8  2022
# 2022-08-25 114.23 116.72 114.11 116.65  16956794      8  2022
# 2022-08-24 113.50 114.78 112.87 113.69  17734624      8  2022

# %% [markdown]
# ### <a name='9'></a> Ćwiczenie 129
# Usuń na stałe kolumny _Year_ i _Month_ z obiektu _google_. Wyświetl obiekt _google_.

# %%
# tutaj wpisz rozwiązanie

google.drop(['Year', 'Month'], axis=1, inplace=True)
google.head()
# Out:
#              Open   High    Low  Close    Volume
# Date
# 2022-08-30 110.17 110.50 107.80 108.94  27513255
# 2022-08-29 109.99 110.95 108.80 109.42  21191157
# 2022-08-26 114.72 115.12 110.19 110.34  37245697
# 2022-08-25 114.23 116.72 114.11 116.65  16956794
# 2022-08-24 113.50 114.78 112.87 113.69  17734624

# %% [markdown]
# ### <a name='10'></a> Ćwiczenie 130
# Przypisz polskie nazwy kolumn (bez polskich znaków):
# * Open -> Otwarcie
# * High -> Najwyzszy
# * Low -> Najnizszy
# * Close -> Zamkniecie
# * Volume -> Wolumen
#
# do obiektu _google_. Wyświetl obiekt _google_.

# %%
# tutaj wpisz rozwiązanie

google.columns
# Out:
# Index(['Open', 'High', 'Low', 'Close', 'Volume'], dtype='object')

# %%
google.rename(columns={'Open':'Otwarcie', 'High':'Najwyzszy', 'Low':'Najnizszy', 'Close':'Zamkniecie', 'Volume':'Wolumen'}, inplace=True)
google.head()
# Out:
#             Otwarcie  Najwyzszy  Najnizszy  Zamkniecie   Wolumen
# Date
# 2022-08-30    110.17     110.50     107.80      108.94  27513255
# 2022-08-29    109.99     110.95     108.80      109.42  21191157
# 2022-08-26    114.72     115.12     110.19      110.34  37245697
# 2022-08-25    114.23     116.72     114.11      116.65  16956794
# 2022-08-24    113.50     114.78     112.87      113.69  17734624
